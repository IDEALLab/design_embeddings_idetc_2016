# %%
% run semantic_space
# Out:
# Using Theano backend.
# Source: sf_s_nonlinear | B-spline control points: 20 | Semantic features: 2 | Training samples: 115 | Testing samples: 13
# Using the existing input file.
# 1 - Processing: [  2.48906902   1.91675609   3.           6.42768707  14.48906902
#   13.91675609]
# 2 - Processing: [  5.30724909   2.0431399    3.           3.73589081  17.30724909
#   14.0431399 ]
# Failed to converge. Trying another.
# 3 - Processing: [  2.12738509   3.523682     3.           8.39629691  14.12738509
#   15.523682  ]
# 4 - Processing: [  5.43930736   2.88390728   3.           4.44459992  17.43930736
#   14.88390728]
# 5 - Processing: [  3.08643655   2.73538197   3.           6.64894542  15.08643655
#   14.73538197]
# 6 - Processing: [  1.23844423   4.99438142   3.          10.75593719  13.23844423
#   16.99438142]
# 7 - Processing: [  5.12717411   4.38749764   3.           6.26032353  17.12717411
#   16.38749764]
# ...

# %%
% run metrics
# Out:
# metrics_glass.png saved!
# metrics_sf_linear.png saved!
# metrics_sf_s_nonlinear.png saved!
# metrics_sf_v_nonlinear.png saved!
